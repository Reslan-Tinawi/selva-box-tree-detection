# %%
from datasets import load_dataset

# %%
train_data = load_dataset("CanopyRS/SelvaBox", split="train")
# Out:
# ...
# Loading dataset shards:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
test_data = load_dataset("CanopyRS/SelvaBox", split="test")
# Out:
# ...
# Loading dataset shards:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
valid_data = load_dataset("CanopyRS/SelvaBox", split="validation")
# Out:
# ...
# Resolving data files:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
train_data
# Out:
# Dataset({
#     features: ['height', 'width', 'fold', 'raster_name', 'location', 'image', 'tile_name', 'annotations', 'tile_metadata'],
#     num_rows: 585
# })

# %%
test_data
# Out:
# Dataset({
#     features: ['height', 'width', 'fold', 'raster_name', 'location', 'image', 'tile_name', 'annotations', 'tile_metadata'],
#     num_rows: 1477
# })

# %%
valid_data
# Out:
# Dataset({
#     features: ['height', 'width', 'fold', 'raster_name', 'location', 'image', 'tile_name', 'annotations', 'tile_metadata'],
#     num_rows: 387
# })

# %%
train_data.save_to_disk('../data/selvabox/train')
test_data.save_to_disk('../data/selvabox/test')
valid_data.save_to_disk('../data/selvabox/validation')
# Out:
# ...
# Saving the dataset (0/6 shards):   0%|          | 0/387 [00:00<?, ? examples/s]
